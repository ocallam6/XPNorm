# %%
import numpy as np

# %%
from astropy.coordinates import SkyCoord

from dustmaps.edenhofer2023 import Edenhofer2023Query
from dustmaps.bayestar import BayestarQuery
import astropy.units as u
import matplotlib.pyplot as plt
# Note that below, we could use version='bayestar2017' to get the newer
# version of the map. Note, however, that the reddening units are not
# identical in the two versions of the map. See Green et al. (2018) for
# an explanation of the units.
eden = Edenhofer2023Query()
bayestar = BayestarQuery()
# Out:
# Optimizing map for querying (this might take a couple of seconds)...
# Loading pixel_info ...
# Loading samples ...
# Loading best_fit ...
# Replacing NaNs in reliable distance estimates ...
# Sorting pixel_info ...
# Extracting hp_idx_sorted and data_idx at each nside ...
#   nside = 64
#   nside = 128
#   nside = 256
#   nside = 512
#   nside = 1024
# t = 45.179 s
#   pix_info:   0.790 s
#    samples:  27.840 s
#       best:   5.343 s
#        nan:   0.053 s
#       sort:  10.991 s
#        idx:   0.162 s

# %% [markdown]
# Bayestar

# %% [markdown]
# 2 Cloud regions

# %%
ra,dec=191.2318,45.1060
galactic_coord = SkyCoord(ra=ra*u.deg, dec=dec*u.deg, frame='icrs')
galactic_coord = galactic_coord.transform_to('galactic')
l=galactic_coord.l.value
b=galactic_coord.b.value

# %%
b
# Out:
# 71.97526214008724

# %%
b
# Out:
# 71.97526214008724

# %%
coords = SkyCoord(l*u.deg, b*u.deg,distance = np.arange(10,  2000, 5)*u.pc, frame='galactic')
plt.scatter(np.arange(10,  2000, 5),2.742*bayestar(coords)/3.1,s=1,color='black')

# %%
for theta in np.arange(0,8,0.2):
    for j in np.arange(0,0.16,0.01):
        l,b=104.08+j*np.cos(theta),22.31+j*np.sin(theta)

        coords = SkyCoord(l*u.deg, b*u.deg,distance = np.arange(10,  2000, 5)*u.pc, frame='galactic')
        plt.scatter(np.arange(10,  2000, 5),2.742*bayestar(coords)/3.1,s=1,color='black')

# %% [markdown]
# Single cloud regions

# %%
for theta in np.arange(0,8,0.2):
    for j in np.arange(0,0.16,0.01):
        l,b=103.9+j*np.cos(theta),21.97+j*np.sin(theta)

        coords = SkyCoord(l*u.deg, b*u.deg,distance = np.arange(10,  2000, 5)*u.pc, frame='galactic')
        plt.scatter(np.arange(10,  2000, 5),2.742*bayestar(coords)/3.1,s=1,color='black')

# %% [markdown]
# Eden

# %%
for theta in np.arange(0,8,0.2):
    for j in np.arange(0,0.16,0.01):
        l,b=104.08+j*np.cos(theta),22.31+j*np.sin(theta)

        coords = SkyCoord(l*u.deg, b*u.deg,distance = np.arange(10,  2000, 5)*u.pc, frame='galactic')
        plt.scatter(np.arange(10,  2000, 5),2.742*eden(coords)/3.1,s=1,color='black')

# %%
for theta in np.arange(0,8,0.2):
    for j in np.arange(0,0.16,0.01):
        l,b=103.9+j*np.cos(theta),21.97+j*np.sin(theta)

        coords = SkyCoord(l*u.deg, b*u.deg,distance = np.arange(10,  2000, 5)*u.pc, frame='galactic')
        plt.scatter(np.arange(10,  2000, 5),2.742*eden(coords)/3.1,s=1,color='black')

# %% [markdown]
# Nice plot

# %%
for theta in np.arange(0,8,0.2):
    for j in np.arange(0,0.16,0.01):
        l,b=104.08+j*np.cos(theta),22.31+j*np.sin(theta)

        coords = SkyCoord(l*u.deg, b*u.deg,distance = np.arange(10,  2000, 5)*u.pc, frame='galactic')
        plt.scatter(np.arange(10,  2000, 5),2.742*bayestar(coords)/3.1,s=1,color='black')
for theta in np.arange(0,8,0.2):
    for j in np.arange(0,0.16,0.01):
        l,b=104.08+j*np.cos(theta),22.31+j*np.sin(theta)

        coords = SkyCoord(l*u.deg, b*u.deg,distance = np.arange(10,  2000, 5)*u.pc, frame='galactic')
        plt.scatter(np.arange(10,  2000, 5),2.742*eden(coords)/3.1,s=1,color='black')

# %%
theta=0
i=0
j=0
l,b=104.08+j*np.cos(theta),22.31+j*np.sin(theta)

coords = SkyCoord(l*u.deg, b*u.deg, frame='galactic')
from dustmaps.planck import PlanckQuery
planck = PlanckQuery()
ebv = planck(coords)

# %%
from dustmaps.sfd import SFDQuery
sfd = SFDQuery()
ebv = sfd(coords)

# %%
ebv* 2.742/3.1
# Out:
# 0.17539952556933128

# %%
for theta in np.arange(0,8,0.2):
    for j in np.arange(0,0.16,0.01):
        l,b=104.08+j*np.cos(theta),22.31+j*np.sin(theta)

        coords = SkyCoord(l*u.deg, b*u.deg,distance = np.arange(10,  2000, 5)*u.pc, frame='galactic')
        plt.scatter(np.arange(10,  2000, 5),2.742*bayestar(coords)/3.1,s=1,color='black')
for theta in np.arange(0,8,0.2):
    for j in np.arange(0,0.16,0.01):
        l,b=104.08+j*np.cos(theta),22.31+j*np.sin(theta)

        coords = SkyCoord(l*u.deg, b*u.deg,distance = np.arange(10,  2000, 5)*u.pc, frame='galactic')
        plt.scatter(np.arange(10,  2000, 5),2.742*eden(coords)/3.1,s=1,color='black')

# %% [markdown]
# # Two clouds

# %%
avs=[]
planck = PlanckQuery()
for theta in np.arange(0, 8, 0.2):
    for j in np.arange(0, 0.16, 0.01):
        l, b = 104.08 + j * np.cos(theta), 22.31 + j * np.sin(theta)

        coords = SkyCoord(l * u.deg, b * u.deg, distance=np.arange(10, 2500, 5) * u.pc, frame='galactic')
        Av_planck = planck(coords)
        avs.append(Av_planck)

# %%
np.stack(avs).flatten().mean()
# Out:
# 0.1565784

# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.coordinates import SkyCoord
import astropy.units as u

fig, axs = plt.subplots(1, 2, figsize=(8, 3))


for theta in np.arange(0, 8, 0.2):
    for j in np.arange(0, 0.16, 0.01):
        l, b = 104.08 + j * np.cos(theta), 22.31 + j * np.sin(theta)

        coords = SkyCoord(l * u.deg, b * u.deg, distance=np.arange(10, 2500, 5) * u.pc, frame='galactic')
        axs[0].scatter(np.arange(10, 2500, 5), 2.742 * bayestar(coords) / 3.1, s=1, color='black')

axs[0].set_title('Bayestar (2019)')
axs[0].set_xlabel('Distance (pc)')
axs[0].set_ylabel('$E(B-V)$')
axs[0].tick_params(axis='both', which='major')
points = [(346, 393), (1250, 2140)]
for point in points:
    axs[0].axvline(x=point[0], color='green', linewidth=1)
    axs[0].axvline(x=point[1], color='green', linewidth=1)

for theta in np.arange(0, 8, 0.2):
    for j in np.arange(0, 0.16, 0.01):
        l, b = 104.08 + j * np.cos(theta), 22.31 + j * np.sin(theta)

        coords = SkyCoord(l * u.deg, b * u.deg, distance=np.arange(10, 2500, 5) * u.pc, frame='galactic')
        axs[1].scatter(np.arange(10, 2500, 5), 2.742 * eden(coords) / 3.1, s=1, color='black')

axs[1].set_title('Edenhofer et al. (2023)')
axs[1].set_xlabel('Distance (pc)')
axs[1].set_ylabel('Differential Extinction')
axs[1].tick_params(axis='both', which='major')
points = [(346, 393), (1250, 2140)]
for point in points:
    axs[1].axvline(x=point[0], color='green', linewidth=1)
    axs[1].axvline(x=point[1], color='green', linewidth=1)
plt.tight_layout()
fig.savefig('/Users/mattocallaghan/XPNorm/Plots/compare_2cloud.png')
plt.show()

# %% [markdown]
# One Cloud

# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.coordinates import SkyCoord
import astropy.units as u

fig, axs = plt.subplots(1, 2, figsize=(8, 3))


for theta in np.arange(0, 8, 0.2):
    for j in np.arange(0, 0.16, 0.01):
        l,b=103.9+j*np.cos(theta),21.97+j*np.sin(theta)

        coords = SkyCoord(l * u.deg, b * u.deg, distance=np.arange(10, 2500, 5) * u.pc, frame='galactic')
        axs[0].scatter(np.arange(10, 2500, 5), 2.742 * bayestar(coords) / 3.1, s=1, color='black')

axs[0].set_title('Bayestar (2019)')
axs[0].set_xlabel('Distance (pc)')
axs[0].set_ylabel('$E(B-V)$')
axs[0].tick_params(axis='both', which='major')
points = [(346, 393), (1250, 2140)]
for point in points:
    axs[0].axvline(x=point[0], color='green', linewidth=1)
    axs[0].axvline(x=point[1], color='green', linewidth=1)

for theta in np.arange(0, 8, 0.2):
    for j in np.arange(0, 0.16, 0.01):
        l, b = 103.9+j*np.cos(theta),21.97+j*np.sin(theta)

        coords = SkyCoord(l * u.deg, b * u.deg, distance=np.arange(10, 2500, 5) * u.pc, frame='galactic')
        axs[1].scatter(np.arange(10, 2500, 5), 2.742 * eden(coords) / 3.1, s=1, color='black')

axs[1].set_title('Edenhofer et al. (2023)')
axs[1].set_xlabel('Distance (pc)')
axs[1].set_ylabel('Differential Extinction')
axs[1].tick_params(axis='both', which='major')
points = [(346, 393), (1250, 2140)]
for point in points:
    axs[1].axvline(x=point[0], color='green', linewidth=1)
    axs[1].axvline(x=point[1], color='green', linewidth=1)
plt.tight_layout()
fig.savefig('/Users/mattocallaghan/XPNorm/Plots/one_cloud_compare.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.coordinates import SkyCoord
import astropy.units as u

fig, axs = plt.subplots(1, 2, figsize=(8, 3))


for theta in np.arange(0, 8, 0.2):
    for j in np.arange(0, 0.16, 0.01):
        l,b=191.2318+j*np.cos(theta),57.1060+j*np.sin(theta)

        coords = SkyCoord(l * u.deg, b * u.deg, distance=np.arange(10, 2500, 5) * u.pc, frame='galactic')
        axs[0].scatter(np.arange(10, 2500, 5), 2.742 * bayestar(coords) / 3.1, s=1, color='black')

axs[0].set_title('Bayestar (2019)')
axs[0].set_xlabel('Distance (pc)')
axs[0].set_ylabel('$E(B-V)$')
axs[0].tick_params(axis='both', which='major')
points = [(346, 393), (1250, 2140)]
for point in points:
    axs[0].axvline(x=point[0], color='green', linewidth=1)
    axs[0].axvline(x=point[1], color='green', linewidth=1)

for theta in np.arange(0, 8, 0.2):
    for j in np.arange(0, 0.16, 0.01):
        l,b=191.2318+j*np.cos(theta),57.1060+j*np.sin(theta)

        coords = SkyCoord(l * u.deg, b * u.deg, distance=np.arange(10, 2500, 5) * u.pc, frame='galactic')
        axs[1].scatter(np.arange(10, 2500, 5), 2.742 * eden(coords) / 3.1, s=1, color='black')

axs[1].set_title('Edenhofer et al. (2023)')
axs[1].set_xlabel('Distance (pc)')
axs[1].set_ylabel('Differential Extinction')
axs[1].tick_params(axis='both', which='major')
for point in points:
    axs[1].axvline(x=point[0], color='green', linewidth=1)
    axs[1].axvline(x=point[1], color='green', linewidth=1)
plt.tight_layout()
fig.savefig('/Users/mattocallaghan/XPNorm/Plots/low_ext_compare.png')
plt.show()

# %%
avs=[]
planck = PlanckQuery()
for theta in np.arange(0, 8, 0.2):
    for j in np.arange(0, 0.16, 0.01):
        l, b = 103.9+j*np.cos(theta),21.97+j*np.sin(theta)

        coords = SkyCoord(l * u.deg, b * u.deg, distance=np.arange(10, 2500, 5) * u.pc, frame='galactic')
        Av_planck = planck(coords)
        avs.append(Av_planck)

# %%
l, b = 103.9,21.97

coords = SkyCoord(l * u.deg, b * u.deg, distance=np.arange(10, 2500, 5) * u.pc, frame='galactic')
Av_planck = planck(coords)

# %%
Av_planck
# Out:
# array([0.15994586, 0.15994586, 0.15994586, 0.15994586, 0.15994586,
#        0.15994586, 0.15994586, 0.15994586, 0.15994586, 0.15994586,
#        0.15994586, 0.15994586, 0.15994586, 0.15994586, 0.15994586,
#        0.15994586, 0.15994586, 0.15994586, 0.15994586, 0.15994586,
#        0.15994586, 0.15994586, 0.15994586, 0.15994586, 0.15994586,
#        0.15994586, 0.15994586, 0.15994586, 0.15994586, 0.15994586,
#        0.15994586, 0.15994586, 0.15994586, 0.15994586, 0.15994586,
#        0.15994586, 0.15994586, 0.15994586, 0.15994586, 0.15994586,
#        0.15994586, 0.15994586, 0.15994586, 0.15994586, 0.15994586,
#        0.15994586, 0.15994586, 0.15994586, 0.15994586, 0.15994586,
#        0.15994586, 0.15994586, 0.15994586, 0.15994586, 0.15994586,
#        0.15994586, 0.15994586, 0.15994586, 0.15994586, 0.15994586,
#        0.15994586, 0.15994586, 0.15994586, 0.15994586, 0.15994586,
#        0.15994586, 0.15994586, 0.15994586, 0.15994586, 0.15994586,
# ...
